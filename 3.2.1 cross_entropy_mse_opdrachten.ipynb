# %% [markdown]
# # Opdrachten: Cross-Entropy en MSE
#
# Beantwoord onderstaande 10 opdrachten. Reken waar mogelijk **met de hand** of met Python.

# %% [markdown]
# **1. MSE (1 datapunt)**
#
# Voorspelling: $\hat{y}=3.5$, Waarde: $y=5$.
# Bereken de Mean Squared Error.

# %%
# Werk hier je berekening uit

# %% [markdown]
# **2. MSE (meerdere datapunten)**
#
# $y=[2,4,6]$, $\hat{y}=[3,5,5]$.
# Bereken de MSE.

# %%
# Werk hier je berekening uit

# %% [markdown]
# **3. MSE (perfecte voorspelling)**
#
# $y=[1,2,3]$, $\hat{y}=[1,2,3]$.
# Wat is de MSE en waarom?

# %%
# Werk hier je berekening uit

# %% [markdown]
# **4. MSE en schaal**
#
# $y=[10,20]$, $\hat{y}=[8,25]$.
# Bereken de MSE.

# %%
# Werk hier je berekening uit

# %% [markdown]
# **5. Binaire cross-entropy (1 voorbeeld)**
#
# Werkelijke label: $y=1$, voorspelde kans: $p=0.9$.
# Bereken de cross-entropy.

# %%
# Werk hier je berekening uit

# %% [markdown]
# **6. Binaire cross-entropy (fout model)**
#
# Werkelijke label: $y=1$, voorspelde kans: $p=0.1$.
# Bereken de cross-entropy.

# %%
# Werk hier je berekening uit

# %% [markdown]
# **7. Binaire cross-entropy (negatieve klasse)**
#
# $y=0$, $p=0.2$.
# Bereken het verlies.

# %%
# Werk hier je berekening uit

# %% [markdown]
# **8. Cross-entropy (meerdere voorbeelden)**
#
# $y=[1,0,1]$, $p=[0.8,0.4,0.6]$.
# Bereken de gemiddelde cross-entropy.

# %%
# Werk hier je berekening uit
